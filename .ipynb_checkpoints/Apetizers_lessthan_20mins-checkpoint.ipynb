# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("E:\ML\Datasets\indian_receipie.csv")

# %%
dataset.shape
# Out:
# (6871, 15)

# %%
dataset.head(10)
# Out:
#    Srno                                         RecipeName  \
# 0     1                               Masala Karela Recipe
# 1     2  टमाटर पुलियोगरे रेसिपी - Spicy Tomato Rice (Re...
# 2     3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3     4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4     5  आंध्रा स्टाइल आलम पचड़ी रेसिपी - Adrak Chutney ...
# 5     6  Pudina Khara Pongal Recipe (Rice and Lentils C...
# 6     7         Udupi Style Ash Gourd Coconut Curry Recipe
# 7     8            Mexican Style Black Bean Burrito Recipe
# 8     9                   Spicy Crunchy Masala Idli Recipe
# 9    10  गोभी के पत्तो की चटनी रेसिपी - Cauliflower Lea...
#
#                                 TranslatedRecipeName  \
# 0                               Masala Karela Recipe
# 1                         Spicy Tomato Rice (Recipe)
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3  Gongura Chicken Curry Recipe - Andhra Style Go...
# ...

# %%
col_drop=['Srno','RecipeName','Ingredients','TranslatedIngredients','CookTimeInMins','TotalTimeInMins','Servings','Cuisine','Diet','Instructions','TranslatedInstructions','TranslatedInstructions','URL']
dataset.drop(col_drop,axis=1,inplace=True)
dataset.head()
# Out:
#                                 TranslatedRecipeName  PrepTimeInMins  \
# 0                               Masala Karela Recipe              15
# 1                         Spicy Tomato Rice (Recipe)               5
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...              20
# 3  Gongura Chicken Curry Recipe - Andhra Style Go...              15
# 4  Andhra Style Alam Pachadi Recipe - Adrak Chutn...              10
#
#                    Course
# 0               Side Dish
# 1             Main Course
# 2  South Indian Breakfast
# 3                   Lunch
# 4  South Indian Breakfast

# %%
dataset.head(20)
# Out:
#                                  TranslatedRecipeName  PrepTimeInMins  \
# 0                                Masala Karela Recipe              15
# 1                          Spicy Tomato Rice (Recipe)               5
# 2   Ragi Semiya Upma Recipe - Ragi Millet Vermicel...              20
# 3   Gongura Chicken Curry Recipe - Andhra Style Go...              15
# 4   Andhra Style Alam Pachadi Recipe - Adrak Chutn...              10
# 5   Pudina Khara Pongal Recipe (Rice and Lentils C...              10
# 6          Udupi Style Ash Gourd Coconut Curry Recipe              10
# 7             Mexican Style Black Bean Burrito Recipe              10
# 8                    Spicy Crunchy Masala Idli Recipe              10
# 9        Cauliflower Leaves Chutney (Recipe in Hindi)               5
# 10  Homemade Baked Beans Recipe (Wholesome & Healthy)              60
# 11                    Veg Chili Cheese Burgers Recipe              10
# ...

# %%
appetizer_data=dataset[dataset["Course"]=="Appetizer"]

# %%
preptime_20=appetizer_data[appetizer_data["PrepTimeInMins"]<20]
preptime_20.head()
# Out:
#                                  TranslatedRecipeName  PrepTimeInMins  \
# 18                         Homemade Tater Tots Recipe              15
# 27  Spinach Garlic Bruschetta Recipe With Red Bell...              10
# 32  Cabbage, Spinach, Pomegranate Slaw with Lemon ...              15
# 37               Chettinad Style Chicken Roast Recipe              15
# 97              Tamil Nadu Style Spicy Egg Fry Recipe               5
#
#        Course
# 18  Appetizer
# 27  Appetizer
# 32  Appetizer
# 37  Appetizer
# 97  Appetizer
