# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("E:\ML\Datasets\indian_receipie.csv")

dataset.shape
# Out:
# (6871, 15)

# %%
dataset.head()
# Out:
#    Srno                                         RecipeName  \
# 0     1                               Masala Karela Recipe
# 1     2  टमाटर पुलियोगरे रेसिपी - Spicy Tomato Rice (Re...
# 2     3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3     4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4     5  आंध्रा स्टाइल आलम पचड़ी रेसिपी - Adrak Chutney ...
#
#                                 TranslatedRecipeName  \
# 0                               Masala Karela Recipe
# 1                         Spicy Tomato Rice (Recipe)
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
#
#                                          Ingredients  \
# 0  6 Karela (Bitter Gourd/ Pavakkai) - deseeded,S...
# 1  2-1/2 कप चावल - पका ले,3 टमाटर,3 छोटा चमच्च बी...
# 2  1-1/2 cups Rice Vermicelli Noodles (Thin),1 On...
# 3  500 grams Chicken,2 Onion - chopped,1 Tomato -...
# ...

# %%
dataset.sort_values(by = "Cuisine", inplace = True) 
dataset.head(1000)
# Out:
#        Srno                                         RecipeName  \
# 3468   4352  Lavand-E-Murgh Recipe - Afghani Chicken In Yog...
# 3579   4531  Afghani Dhoog Recipe - Cucumber Mint Buttermil...
# 4917   6881   Malida Recipe (Healthy Whole Wheat Afghan Sweet)
# 5286   7660  Moroccan Chickpeas And Vegetable Stew Recipe W...
# 734     801                            Vegetable Tagine Recipe
# ...     ...                                                ...
# 5924   9256                      Homemade Harissa Paste Recipe
# 5920   9238  Healthy Yogurt Parfait with Oats and Fresh Fru...
# 6254  10303  Egg Salad Recipe With Sun Dried Tomatoes And S...
# 2228   2581                               Papaya Sorbet Recipe
# 2254   2611    Chocolate And Oats Christmas Cookie Cake Recipe
#
#                                    TranslatedRecipeName  \
# 3468  Lavand-E-Murgh Recipe - Afghani Chicken In Yog...
# 3579  Afghani Dhoog Recipe - Cucumber Mint Buttermil...
# ...
